# %%
#1

# %%
a=[1,2,3,4]
b=[sum(a[0:x+1]) for x in range(0,len(a))]
print(b)
# Out:
# [1, 3, 6, 10]

# %%
len(a)
# Out:
# 4

# %%
[*range(0,4)]
# Out:
# [0, 1, 2, 3]

# %%
sum(a[0:1])
# Out:
# 1

# %%
sum(a[0:2])
# Out:
# 3

# %%
sum(a[0:3])
# Out:
# 6

# %%
sum(a[0:4])
# Out:
# 10

# %%
print([sum(a[0:1]),sum(a[0:2]),sum(a[0:3]),sum(a[0:4])])
# Out:
# [1, 3, 6, 10]

# %%
#2

# %%
L1 = []
L1.append([1, [2, 3], 4])
L1.extend([7, 8, 9])
print(L1[0][1][1] + L1[2])
# Out:
# 11

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
L1 = []
L1.append([1, [2, 3], 4])
L1
# Out:
# [[1, [2, 3], 4]]

# %%
L1.extend([7, 8, 9])
L1
# Out:
# [[1, [2, 3], 4], 7, 8, 9]

# %%
print(L1[0][1][1] + L1[2])
# Out:
# 11

# %%
#3

# %%
T = (1, 2, 3, 4, 5, 6, 7, 8)
print(T[T.index(5)], end = " ")
print(T[T[T[6]-3]-6])
# Out:
# 5 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
T = (1, 2, 3, 4, 5, 6, 7, 8)

# %%
T.index(5) #---> 5 elemanı ----> 4 numaralı indexte
# Out:
# 4

# %%
T[4] # 4'üncü indexte ---> 5 var.
# Out:
# 5

# %%
T[6]
# Out:
# 7

# %%
T[4]
# Out:
# 5

# %%
T[-1]
# Out:
# 8

# %%
#4

# %%
D = {1 : 1, 2 : '2', '1' : 1, '2' : 3}
D['1'] = 2
print(D[D[D[str(D[1])]]])
# Out:
# 3

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
D
# Out:
# {1: 1, 2: '2', '1': 2, '2': 3}

# %%
D[1]
# Out:
# 1

# %%
D['1']
# Out:
# 2

# %%
#5

# %%
set1 = {1, 2, 3}
set2 = set1.copy()
set2.add(4)
print(set1)
# Out:
# {1, 2, 3}

# %%
set1 = {1, 2, 3}
set2 = set1.copy()
set2
# Out:
# {1, 2, 3}

# %%
set2.add(4)
set2
# Out:
# {1, 2, 3, 4}

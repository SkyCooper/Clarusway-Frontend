# %% [markdown]
# ### Code Challenge -1
#
# <div class="alert alert-block alert-info">
#     <b>💡Objective:</b>
#     <ul>
#         <li>To improve your <b>boolean logic</b> and <b>arithmetic operator algorithm</b>&nbsp;skills.</li>
#     </ul>
# </div>
#
# - Using the all following items once each, set a correct boolean expression that returns `write me`. Use the `print()` function to display the result.
#
# ```python
# 0
# and
# not
# "write me"
# ```

# %%
x = not 0 and "write me"
print(x)
# Out:
# write me

# %% [markdown]
# ### Code Challenge-2
#
# Write a program that calculates body mass index from **height** and **weight** variables.
#
# Body mass index :  Weight / Height(m) * Height(m)

# %%
weight = int(input("weight = "))
height = float(input("height = "))
Body_mass_index = weight / (height * height)
print(Body_mass_index)
# Out:
# weight = 72
# height = 1.7
# 24.913494809688583

# %%
weight, height = int(input("weight = ")) ,float(input("height = "))  #daha kısa yapılmış hali
print(weight / (height * height))
# Out:
# weight = 72
# height = 1.7
# 24.913494809688583

# %% [markdown]
# ### Code Challenge-3
#
# With your \$ 200,  How many pieces of material can you get for $ 11 each? How much money do you have left after buying?

# %%
money = 200
price = 11
piece_of_met = money // price
change = money % price
print(piece_of_met, 'piece')
print(change, 'dolar')
# Out:
# 18 piece
# 2 dolar

# %%
money, price = 200, 11   # aynı kod kısaltılmış hali
print(money // price, 'piece')
print(money % price, 'dolar')
# Out:
# 18 piece
# 2 dolar

# %% [markdown]
# ### Code Challenge-4
#
# >Do not run the code, try to figure out in your mind.
#
# What will be the output of the following syntax :
#
# ```python
# print(True and False and (not True and False) and not (True or False))

# %%
print(True and False and (not True and False) and not (True or False))
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Code Challenge-5
#
# >Do not run the code, try to figure out in your mind.
#
# What will be the output of the following syntax :
#
# ```python
# print(True and False and not "False" and None and ("None" or None))
# ```

# %%
print(True and False and not "False" and None and ("None" or None))
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Code Challenge-6
#
# >Do not run the code, try to figure out in your mind.
#
# What will be the output of the following syntax :
#
# ```python
# print("clarusway" and 0 and not "" and False and (" " or None))
# ```

# %%
print("clarusway" and 0 and not "" and False and (" " or None))
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Code Challenge-7
# Ask the user for two numbers and assign these numbers to variables and replace the values of these variables with each other.

# %%
a = input('birinci sayının değeri = ')             # ÇÖZÜM-1
b = input('ikinci sayının değeri = ')
print('birinci sayının değeri =', b)
print('ikinci sayının değeri =', a)
# Out:
# birinci sayının değeri = 11
# ikinci sayının değeri = 22
# birinci sayının değeri = 22
# ikinci sayının değeri = 11

# %%
aa = input('birinci sayının değeri = ')           # ÇÖZÜM-2
bb = input('ikinci sayının değeri = ')
print('birinci sayının değeri = {}\nikinci sayının değeri = {}'.format(bb, aa))
# Out:
# birinci sayının değeri = 11
# ikinci sayının değeri = 22
# birinci sayının değeri = 22
# ikinci sayının değeri = 11

# %%
a , b = input('sayi_1 :'), input('sayi_2 :')        # ÇÖZÜM-3
a, b = b, a
print('sayi_1 :'+ a ,'sayi_2 :'+b)
# Out:
# sayi_1 :11
# sayi_2 :22
# sayi_1 :22 sayi_2 :11

# %%
x, y = 1, 2                # ÇÖZÜM-4
print(x ,y)
x, y = y, x
print(x, y)
# Out:
# 1 2
# 2 1

# %%
x, y = input('Enter value of x: '), input('Enter value of y: ')    # ÇÖZÜM-5
temp, x, y = x, y, temp
print('The value of x after swapping: {}'.format(x))
print('The value of y after swapping: {}'.format(y))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1040/990772257.py in <module>
# ----> 1 x, y = input('Enter value of x: '), input('Enter value of y: ')
#       2 temp, x, y = x, y, temp
#       3 print('The value of x after swapping: {}'.format(x))
#       4 print('The value of y after swapping: {}'.format(y))
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 02 haziran 2022 İf/else ile çözüm ödevi;

# %%
print('Answer these questions only "Yes" or "No" please;')

age = input('Are you a cigarette addict older than 75 years old? ').capitalize()
chronic = input('Do you have a severe chronic disease? ').capitalize()
immune = input('Is your immune system too weak? ').capitalize()

if age == "Yes" or chronic == "Yes" or immune == "Yes":
    print('You are in risky group')
else:
    print('You are not in risky group')
# Out:
# Answer these questions only "Yes" or "No" please;
# Are you a cigarette addict older than 75 years old? no
# Do you have a severe chronic disease? yes
# Is your immune system too weak? no
# You are in risky group

# %%
# Mesut Mentor'un düzelttiği kod

print('Answer these questions only Yes(1)/No(0) please')
age = int(input('Are you a cigarette addict older than 75 years old? '))
chronic = int(input('Do you have a severe chronic disease? '))
immune = int(input('Is your immune system too weak? '))
risk = bool( age or chronic or immune)
print('Do you have risk of death :', (risk and "You have risk of death" or "You have NOT risk"))
# Out:
# Answer these questions only Yes(1)/No(0) please
# Are you a cigarette addict older than 75 years old? No
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4308/105912499.py in <module>
#       2
#       3 print('Answer these questions only Yes(1)/No(0) please')
# ----> 4 age = int(input('Are you a cigarette addict older than 75 years old? '))
#       5 chronic = int(input('Do you have a severe chronic disease? '))
#       6 immune = int(input('Is your immune system too weak? '))
#
# ValueError: invalid literal for int() with base 10: 'No'

# %%
# Kadir Hocanın çÖzümü
age, smoke, chronic, immune = input("age > 75 (y/n): "), input("smoke ? (y/n): "), input("chronic ? (y/n): "), input("immune ? (y/n): ")
risk = (age=="y" or smoke=="y" or chronic=="y" or immune=="y")
#hepsine "n" girilmişse risk = ( False or False or False or False)
# herhangi birisi "n" ise risk = ( False or True or False or False)
print(risk)
# Out:
# age > 75 (y/n): y
# smoke ? (y/n): n
# chronic ? (y/n): y
# immune ? (y/n): n
# True

# %%
#F3602-Mustafa Hocanın Çözümü
age = input("enter your age :")
smoke = input("Are you a cigarette addict? (True/False)")
chronic = input("Do you have a severe chronic disease? (True/False)")
immune = input("Is your immune system too weak? (True/False)")
risk = age or smoke or chronic or immune

if int(age) >= 75 or smoke.startswith("True") or immune.startswith("True") or chronic.startswith("True") :
  print("you are risky")
else :
  print("you don't have risk")
# Out:
# enter your age :80
# Are you a cigarette addict? (True/False)False
# Do you have a severe chronic disease? (True/False)False
# Is your immune system too weak? (True/False)True
# you are risky

# %% [markdown]
# ![image.png](attachment:image.png)
#
# en basit hali ile çözüm böyle de olabilir, çünkü bizden veri girişi istemiyor.

# %%
# Edwin Hoca çözümü, basit düşün saha araştırması yap
age = True
chronic = True
immune = True
risk = age or chronic or immune
risk
# Out:
# True

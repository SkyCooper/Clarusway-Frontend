# %%
28 Mayıs 2022

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# while ---> Condition, True olduğu sürece çalışır, ne zaman False olursa kod çalışması durur.
#
# for   ---> iterator var, yani sayı sayar. Counter kaç ise o kadar kere çalışır.

# %% [markdown]
# # Loops ( For / While)
#
# When writing programs in Python, in some cases it is not enough to execute our block of code only once. The loops are used to repeat (iterate) the execution of a block of code.
#
# As one of the most main functions in programming, loops are an important part of almost every programming language. Loops enable programmers to set certain sections of their code to repeat through a number of loops which are referred to as iterations.

# %% [raw]
# while <şart doğruyken>
#     -->burada yazılanı yap
# else : <yanlış ise>
#     --> bunu yap
#
# while döngüsünde ilave elif olmaz, sadece iki durum kullanılır. Ama doğru/yanlış blokları içinde;
# ilave while/for/if-elif-elif-else döngüleri ayrıca kurulabilir.

# %% [markdown]
# # While loop

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
while 0 : #condition False olduğu için kod çalışmaz
    print("sıfır")

# %%
while 0 : #condition False olduğu için kod çalışmaz
    print("sıfır")
print("bir") # dögüye girmez, sonraki kod çalışır.

# %%
number = 0

while number < 6:
    print(number)
    number += 1
print('now, number is bigger or equal to 6')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# now, number is bigger or equal to 6

# %%
number = 0

while number < 6:
    number += 1      # print'in üstüne aldım, çıktı değişti!!!!
    print(number)
print('now, number is bigger or equal to 6')
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# now, number is bigger or equal to 6

# %%
condition = 5 #---> boolen değeri True

# while condition : ---> her zaman True olacağı için
    # print(condition)  ---> sonsuz döngüye girer.

# %%
condition = 5

while condition :
    print(condition)
    condition -= 1 # ---> 5,4,3,2,1 True am en son sıfır olunca-->False olur ve döngü durur.
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
condition = 5

while True :  # burası Her zaman True olacağı için şart koymazsak sonsuz olur.
    condition -= 1
    print(condition)
        
    if condition == 0 : #--> şimdi şart koyduğumuz için conditionu sayar ve 0 olunca döngüden çıkar.
        break  #---> while True bile olsa break, orayı False yapar ve döngü durur.
# Out:
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_list=["a", "b", "c", "d", "e"]

a = 0

while a < len(my_list):
    print('square of {} is : {}'.format(a, a**2))
    a+=1
# Out:
# square of 0 is : 0
# square of 1 is : 1
# square of 2 is : 4
# square of 3 is : 9
# square of 4 is : 16

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age = "kırk" #strig yaptım

# %%
age.isdigit()  #stringe uygulanır, True/False çıktı verir.

# %%
"15".isdigit() # içindeki numeric olduğu için True verir.
# Out:
# True

# %%
"15.5".isdigit() # float bir değer "15.5" tırnak içinde string olunca "." numeric değil strin algılanır--> False verir
# Out:
# False

# %%
"-15".isdigit()   # -15 de aynı "-" numeric algılanmaz
# Out:
# False

# %%
not 12 #--> direk bool çıktı verir
# Out:
# False

# %%
age = input("yaşınızı giriniz : ") # kullanıcı yanlış giriş yapınca condition True olmalı ki, tekrar giriş yapılsın

while not age.isdigit():
    
    print("Yanlış giriş yaptın!")
    age = input("yaşınızı giriniz : ")
    
print("Doğru giriş yaptın, yaşın:", age)
# Out:
# yaşınızı giriniz : 12,5
# Yanlış giriş yaptın!
# yaşınızı giriniz : -12
# Yanlış giriş yaptın!
# yaşınızı giriniz : 12
# Doğru giriş yaptın, yaşın: 12

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
answer = 44

question = 'What number am I thinking of?  '
print ("Let's play the guessing game!")

while True:
    guess = int(input(question))

    if guess < answer:
        print('Little higher')
    elif guess > answer:
        print('Little lower')
    else:  # guess == answer
        print('Are you a MINDREADER!!!')
        break
# Out:
# Let's play the guessing game!
# What number am I thinking of?  44
# Are you a MINDREADER!!!

# %%
# benim çözüm
num = 5
while True:
    guess = int(input("sayı : "))
    if guess > num :
        print('Little lower')
    elif guess < num :
         print('Little higher')
    else:
        print('Correct!')
        break
# Out:
# sayı : 5
# Correct!

# %%
# faktoriyel hesaplama?
# 6! = 6*5*4*3*2*1 = 720

sayı = int(input("Sayı giriniz :" ))
sonuc = 1

while sayı > 0:
    sonuc = sonuc * sayı
    sayı -= 1
print(sonuc)
# Out:
# Sayı giriniz :5
# 120

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"The best school is Clarusway".split()
# Out:
# ['The', 'best', 'school', 'is', 'Clarusway']

# %%
len("The best school is Clarusway".split())
# Out:
# 5

# %%
sentence = input("Enter a sentence : ")
# Out:
# Enter a sentence : The best school is Clarusway

# %%
word_list = sentence.split()
print(word_list)
print(len(word_list[0]))
# Out:
# ['The', 'best', 'school', 'is', 'Clarusway']
# 3

# %%
sentence = input("Enter a sentence : ")
word_list = sentence.split()


longest = 0 # her seferinde uzun kelimeyi bulunca burası değişecek
i = 0 # index numarsını tekrar ettirmek için atandı, her seferinde artacak

while i < len(word_list) : # cümlenin uzunluğu 5, yani içinde 0,1,2,3,4 e kadar index var. i=4 oluncaya kadar çalış
    if len(word_list[i]) > longest :                                                     # i=5 olursa False olur döngü biter.
        longest = len(word_list[i])
    i += 1 # counter'ı if bloğu dışına alıyoruz. ÖNEMLİ

print("The lenght of the longest word :", longest)
# Out:
# Enter a sentence : The best school is Clarusway
# The lenght of the longest word : 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
flowers = ['Rose', 'Orchid', 'Tulip']
count1 = len(flowers)
count2 = 0

while count1 > count2 :
    print(flowers[count2])
    count2 += 1
# Out:
# Rose
# Orchid
# Tulip

# %%
# Write a program that takes a number from the user, assigns it to the variable (number),
# and prints the squares of all numbers between 0 and the number (not included) entered by the user.
# Note: Write the program with while statement.

number = int(input('Please enter a number: '))
counter = 0
while counter < number:
    print(counter**2)
    counter += 1
# Out:
# Please enter a number: 5
# 0
# 2
# 4
# 6
# 8

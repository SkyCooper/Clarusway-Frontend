# %%
#--->1

# %%
def san(x):
    print(x+1)
    x=-2
    x=4
    # print(x)
san(12)
# Out:
# 13
# 4

# %%
#--->>> 2

# %%
def foo(fname, val):
    print(fname(val))
foo(max, [1, 2, 3])
foo(min, [1, 2, 3])
# Out:
# 3
# 1

# %%
#---->>3

# %%
count = 0
my_string = "Clarusway"
my_char = "a"
for i in my_string:
    if i == my_char:
        count += 1
print(count)
# Out:
# 2

# %%
def count(item,word):
  return len(word.split(item))-1

count("a", "clarusway")  # kelime/karakter saydırma fonksiyonu
# Out:
# 2

# %%
#--->4

# %%
num = 2013
reversed_num = 0
while num != 0:
    digit = num % 10
    reversed_num = reversed_num * 10 + digit
    num //= 10
print(reversed_num)
# Out:
# 3102

# %%
#----> 5

# %%
f=lambda x:bool(x%2)
print(f(20), f(21))
# Out:
# False True

# %%
#---->6

# %%
import random
random.randrange(0,91,5)
# Out:
# 55

# %%
random.randrange
# Out:
# <bound method Random.randrange of <random.Random object at 0x000001CB84700360>>

# %%
#---->7

# %%
def foo():
    try:
        return 1
    finally:
        return 2
    
k = foo()
print(k)
# Out:
# 2

# %%
#--->8

# %%
x=6
y=8
assert x>y, 'X too small'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7072/2865098675.py in <module>
#       1 x=6
#       2 y=8
# ----> 3 assert x>y, 'cooper'
#
# AssertionError: cooper

# %%
 # ---> 10

# %%
valid = False
while not valid:
    try:
        n=int(input("Enter a number"))
        while n%2==0:
            print("Bye")
        valid = True
    except ValueError:
        print("Invalid")
# Out:
# Enter a number6
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# Bye
# ...
